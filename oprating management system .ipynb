# %%
import os

def current_file():
    files = os.listdir()
    print(files)

def create_file():
    create = input("enter file_name: ")
    try:
        os.mkdir(create)
        print(create, 'created successfully')
    except:
        print("failed to create")
def search_file ():
    filename = input("enter the file name which you want to search: ")
    try:
        print(filename)
    except FileNotFoundError:
        print("file doen't exist")

def rename_file():
    old_filename = input('enter the old name of file: ')
    new_filename = input("enter the new name of file: ")
    os.rename(old_filename, new_filename)
    print("file renamed successfully")
def delete_file():
    delete_filename = input("enter the file name which you want to delete: ")
    try:
        os.remove(delete_filename)
        print(delete_filename, 'deleted successfully')
    except Exception:
        print("file not found")

while True:
    print("Press 1 to current file list")
    print("Press 2 to search file")
    print("Press 3 to rename the file")
    print("Press 4 to delete the file")

    choose = input("enter your choice: ")
    if choose == '1':
        current_file()
    elif choose == '2':
        search_file()
    elif choose == '3':
        rename_file()
    elif choose == '4':
        delete_file()
    else:

# %%
import os

def current_file():
    files = os.listdir()
    print("\nFiles in directory:")
    for file in files:
        print(file)

def create_file():
    name = input("Enter file name to create: ")
    try:
        os.mkdir(name)
        print(f"{name} created successfully")
    except FileExistsError:
        print("File already exists")

def search_file():
    filename = input("Enter file name to search: ")
    if os.path.exists(filename):
        print(f"{filename} exists ✅")
    else:
        print("File does not exist ❌")

def rename_file():
    old_name = input("Enter old file name: ")
    new_name = input("Enter new file name: ")
    
    if os.path.exists(old_name):
        os.rename(old_name, new_name)
        print("File renamed successfully")
    else:
        print("File not found")

def delete_file():
    filename = input("Enter file name to delete: ")
    
    if os.path.exists(filename):
        os.remove(filename)
        print(f"{filename} deleted successfully")
    else:
        print("File not found")

while True:
    print("\n===== FILE MANAGER =====")
    print("1. Show files")
    print("2. Create file")
    print("3. Search file")
    print("4. Rename file")
    print("5. Delete file")
    print("6. Exit")

    choice = input("Enter your choice: ")

    if choice == '1':
        current_file()
    elif choice == '2':
        create_file()
    elif choice == '3':
        search_file()
    elif choice == '4':
        rename_file()
    elif choice == '5':
        delete_file()
    elif choice == '6':
        print("Exiting program...")
        break
    else:
        print("Invalid choice")
# Out:
# ===== FILE MANAGER =====
# 1. Show files
# 2. Create file
# 3. Search file
# 4. Rename file
# 5. Delete file
# 6. Exit
# Enter your choice:  2
# Enter file name to create:  omt
# omt created successfully
#
# ===== FILE MANAGER =====
# 1. Show files
# 2. Create file
# 3. Search file
# 4. Rename file
# 5. Delete file
# 6. Exit
# Enter your choice:  1
# Files in directory:
# .anaconda
# .conda
# .condarc
# .continuum
# .dotnet
# .ipynb_checkpoints
# .ipython
# .jupyter
# .local
# .matplotlib
# .templateengine
# .vscode
# anaconda3
# anaconda_projects
# AppData
# Application Data
# cal.ipynb
# calculator.project.ipynb
# Contacts
# Cookies
# CrossDevice
# dict.pratiice.ipynb
# Documents
# Downloads
# Favorites
# imp.ipynb
# Local Settings
# Microsoft
# MT_DIP_AUG_SAML_DEEPAK
# Music
# My Documents
# NetHood
# NTUSER.DAT
# ntuser.dat.LOG1
# ntuser.dat.LOG2
# NTUSER.DAT{7f2adc70-bca0-11ef-af1e-c47e207818ec}.TM.blf
# ...
