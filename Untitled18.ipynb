# %%
a="hello world"

# %%
print(a)
# Out:
# hello world

# %%
print(a[2:5])
# Out:
# llo

# %%
b="hello,world!"
print(b[-5:-2])
# Out:
# orl

# %%
a = "     hello world"
print(a.upper())
# Out:
#      HELLO WORLD

# %%
print(a.lower())
# Out:
#      hello world

# %%
print(a.strip())
# Out:
# hello world

# %%
a="hello "
b="world"
c=a+b
print(c)
# Out:
# hello world

# %%
a="hello "
b="world"
c=a+" "+b
print(c)
# Out:
# hello  world

# %%
age = 36
#This will produce an error:
o=str(age)
txt = "My name is John, I am " + o
print(txt)
# Out:
# My name is John, I am 36

# %%
age=36
txt = "my name is john, I am  {}" 
print(txt.format(age))
# Out:
# my name is john, I am  36

# %%
age = 36
txt =f"My name is John, I am {age}"
print(txt)
# Out:
# My name is John, I am 36

# %%
a=4
b=567
c=49.95
abc="i want {} pieces of item {} for {} doller."
print(abc.format(a,b,c))
# Out:
# i want 4 pieces of item 567 for 49.95 doller.

# %%
txt = "i love apples,apple are my favorite fruit"
x = txt.count("apple", 10,20)
print (x)
# Out:
# 1

# %%
txt="hello, welcome to my world,"
x=txt.find("welcome")
print(
# Out:
# 7

# %%
txt="hello, welcome to my world,"
x=txt.index("welcome")
print(x)
# Out:
# 7

# %%
txt="hello, welcome to my world,"

x=txt.split(",")
print (x)
# Out:
# ['hello', ' welcome to my world', '']

# %%
txt="hello, welcome to my world,"
x=txt.split()
print (x)
# Out:
# ['hello,', 'welcome', 'to', 'my', 'world,']

# %%
dataset=[5,5,6,6,6,7,7,9,9,3]
dataset.sort()
N=len(dataset)
if N%2==0:
    median=(dataset[N//2]+dataset[N//2-1])/2
else:
    median=dataset[N//2]
print(median)
# Out:
# 6.0

# %%
dataset = [2,5,5,5,5,6,6,7]

freq={}

for x in dataset:
    freq[x]=freq.get(x,0)+1

max_freq=max(freq.values())

modes=[]
for k,v in freq.items():
    if v==max_freq:
        modes.append(k)
        print("dataset mode:",modes)
# Out:
# dataset mode: [5]

# %%
+
# Out:
#   Cell In[14], line 1
#     +
#      ^
# SyntaxError: invalid syntax

# %%
dict = {"brand":"Ford","model":"Mustang","year":1964}
print(dict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %%
print(dict["brand"])
# Out:
# Ford

# %%
print(len(dict))
# Out:
# 3

# %%
car_dict2={"brand":"bmw","model":"iX","year":1964,"year":2000}
print(car_dict2)
# Out:
# {'brand': 'bmw', 'model': 'iX', 'year': 2000}

# %%
x=car_dict2.get("model")
print(x)
# Out:
# iX

# %%
car_dict2.values()
# Out:
# dict_values(['bmw', 'iX', 2000])

# %%
d3={"name":"A","year":2023,"pass":True,"Marks":[50,60,70]}
print(d3)
# Out:
# {'name': 'A', 'year': 2023, 'pass': True, 'Marks': [50, 60, 70]}

# %%
d3.update({"year":2024})

# %%
print (d3)
# Out:
# {'name': 'A', 'year': 2024, 'pass': True, 'Marks': [50, 60, 70]}

# %%
d3["phone_no"]=94566
print(d3)
# Out:
# {'name': 'A', 'year': 2024, 'pass': True, 'Marks': [50, 60, 70], 'phone_no': 94566}

# %% [raw]
# d3.update({"email":"adf@gmail"

# %%
print(d3)
# Out:
# {'name': 'A', 'year': 2024, 'pass': True, 'Marks': [50, 60, 70], 'phone_no': 94566}

# %%
d1=["c1","c2","c3","c4"]
for x in d1:
    print(x)
    if x == "banana":
        break
# Out:
# c1
# c2
# c3
# c4

# %%
i = 1
while i < 6:
    print(i)
    i +=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
car_dict={"brand":"BMW","model":"iX","year":1964}
print(car_dict)
# Out:
# {'brand': 'BMW', 'model': 'iX', 'year': 1964}

# %%
print(car_dict['brand'])
# Out:
# BMW

# %%
print(len(car_dict))
# Out:
# 3

# %%
print(type(car_dict))
# Out:
# <class 'dict'>

# %%
car_dict2={"brand":"BMW","model":"iX","year":1964,"year":2000}

# %%
print(car_dict2)
# Out:
# {'brand': 'BMW', 'model': 'iX', 'year': 2000}

# %%
x=car_dict.get("model")
print(x)
# Out:
# iX

# %% [raw]
# car_dict.keys()

# %%
car_dict3={"brand":"BMW","model":"iX","year":2024,"year":2000}
print(car_dict3)
# Out:
# {'brand': 'BMW', 'model': 'iX', 'year': 2000}

# %%
x=car_dict.get("model")
print(x)
# Out:
# iX

# %%
car_dict.values()
# Out:
# dict_values(['BMW', 'iX', 1964])

# %%
car_dict["year"]=2024
print(car_dict)
# Out:
# {'brand': 'BMW', 'model': 'iX', 'year': 2024}

# %%
car_dict["color"]="white"
print(car_dict)
# Out:
# {'brand': 'BMW', 'model': 'iX', 'year': 2024, 'color': 'white'}

# %%
d3={"name":"A","year":2023,"pass":True,"marks":[50,60,70]}
print(d3)
# Out:
# {'name': 'A', 'year': 2023, 'pass': True, 'marks': [50, 60, 70]}

# %%
d3.update({"year":2024})
d3
# Out:
# {'name': 'A', 'year': 2024, 'pass': True, 'marks': [50, 60, 70]}

# %%
d3['phone_no']=1203

# %%
d3['phone_no']=94566
d3
# Out:
# {'name': 'A',
#  'year': 2024,
#  'pass': True,
#  'marks': [50, 60, 70],
#  'phone_no': 94566}

# %%
d3.update({'email':'asdf@gmail.com'})
d3
# Out:
# {'name': 'A',
#  'year': 2024,
#  'pass': True,
#  'marks': [50, 60, 70],
#  'phone_no': 94566,
#  'email': 'asdf@gmail.com'}

# %%
d3.pop('phone_no')
# Out:
# 94566

# %%
d3
# Out:
# {'name': 'A',
#  'year': 2024,
#  'pass': True,
#  'marks': [50, 60, 70],
#  'email': 'asdf@gmail.com'}

# %%
d3.popitem()
# Out:
# ('email', 'asdf@gmail.com')

# %%
del d3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 del d3
#
# NameError: name 'd3' is not defined

# %%
d3.clear()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 d3.clear()
#
# NameError: name 'd3' is not defined

# %%
d3={"name":"A",'year':2023,'Pass':True,'Marks':[50,60,70]}
d3
# Out:
# {'name': 'A', 'year': 2023, 'Pass': True, 'Marks': [50, 60, 70]}

# %%
d4=d3.copy()

# %%
d4
# Out:
# {'name': 'A', 'year': 2023, 'Pass': True, 'Marks': [50, 60, 70]}

# %%
d5=dict(d4)

# %%
d5
# Out:
# {'name': 'A', 'year': 2023, 'Pass': True, 'Marks': [50, 60, 70]}

# %%
myfamily = {
  "child1" : {
    "name" : "Emil",
    "year" : 2004
  },
  "child2" : {
    "name" : "Tobias",
    "year" : 2007
  },
  "child3" : {
    "name" : "Linus",
    "year" : 2011
  }
}

# %%
myfamily
# Out:
# {'child1': {'name': 'Emil', 'year': 2004},
#  'child2': {'name': 'Tobias', 'year': 2007},
#  'child3': {'name': 'Linus', 'year': 2011}}

# %%
myfamily1 = {
    "child1" : {
        "name": "emil",
        "year": "2004"
    },
    "child2":{
        "name":"arush",
        "year":2003
    },
    "child3":{
        "name":"ankit",
        "year":2011
    }
}

# %%
myfamily1
# Out:
# {'child1': {'name': 'emil', 'year': '2004'},
#  'child2': {'name': 'arush', 'year': 2003},
#  'child3': {'name': 'ankit', 'year': 2011}}

# %%
print(myfamily["child2"]["name"])
# Out:
# Tobias

# %%
set1={1,2,3,4,5,6,9}
print(set1)
# Out:
# {1, 2, 3, 4, 5, 6, 9}

# %%
set2={10,11,12}
print(set2)
# Out:
# {10, 11, 12}

# %%
set3={1,2}

# %%
del set3

# %%
print(set3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(set3)
#
# NameError: name 'set3' is not defined

# %%
number = int(input("Enter a number: "))
if number > 0:
    print(f"{number} is a positive number.")
elif number == 0:
    print("The number is zero.")
else:
    print(f"{number} is a negative number.")
# Out:
# Enter a number:  10
# 10 is a positive number.

# %%
a = 200
b = 33

if b > a:
    print("b is greater than a")
else:
    print("b is not greater than a")
# Out:
# b is not greater than a

# %%
num=int(input("enteryour first name:"))
if(num % 2)==0:
    print("number is even")
else:
    print("number is odd")
# Out:
# enteryour first name: 3
# number is odd

# %%
a=10
b=20
a=temp
print(a)
print(b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 a=10
#       2 b=20
# ----> 3 a=temp
#       4 print(a)
#       5 print(b)
#
# NameError: name 'temp' is not defined

# %%
a = 10
b = 20
temp = a  # Define temp variable first, storing the value of a
a = b     # Now a can be safely overwritten with b's value
b = temp  # And b gets the original value of a from temp
print(a)  # Will print 20
print(b)  # Will print 10
# Out:
# 20
# 10

# %%
marks=[94.4,87.5,95.2,66.4,45.1]
print(marks)
