# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Fix: Remove the invisible character from the file path
# The original path had a Left-to-Right Embedding character (\u202a)
df = pd.read_csv(r"C:\Users\Bailw\Downloads\student_marks.csv")

# Alternative approach using forward slashes which works across operating systems
# df = pd.read_csv("C:/Users/Bailw/Downloads/treatments_cut.csv")

# %%
df
# Out:
#   Unnamed: 0 Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0       John      M  05-04-1988     55       45         56       87       21
# 1     Suresh      M  04-05-1987     75       96         78       64       90
# 2     Ramesh      M  25-05-1989     25       54         89       76       95
# 3    Jessica      F  12-08-1990     78       96         86       63       54
# 4   Jennifer      F  02-09-1989     58       96         78       46       96
# 5       Annu      F  05-04-1988     45       87         52       89       55
# 6      pooja      F  04-05-1987     55       64         61       58       75
# 7     Ritesh      M  25-05-1989     54       76         87       56       25
# 8      Farha      F  12-08-1990     55       63         89       75       78
# 9     Mukesh      M  02-09-1989     96       46         77       83       58
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# ...

# %%
# Display First 5 Record 
df.head()
# Out:
#   Unnamed: 0 Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0       John      M  05-04-1988     55       45         56       87       21
# 1     Suresh      M  04-05-1987     75       96         78       64       90
# 2     Ramesh      M  25-05-1989     25       54         89       76       95
# 3    Jessica      F  12-08-1990     78       96         86       63       54
# 4   Jennifer      F  02-09-1989     58       96         78       46       96
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# 2         87       56      74
# 3         89       75      45
# 4         77       83      53

# %%
#Dispaly last 5 Record
df.tail()
# Out:
#   Unnamed: 0 Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 5       Annu      F  05-04-1988     45       87         52       89       55
# 6      pooja      F  04-05-1987     55       64         61       58       75
# 7     Ritesh      M  25-05-1989     54       76         87       56       25
# 8      Farha      F  12-08-1990     55       63         89       75       78
# 9     Mukesh      M  02-09-1989     96       46         77       83       58
#
#    Economics  History  Civics
# 5         89       87      52
# 6         58       64      61
# 7         56       76      87
# 8         75       63      89
# 9         83       46      77

# %%
#Checking no of Rows & columns in dataset
df.shape
# Out:
# (10, 11)

# %%
#Checking all information of Dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  10 non-null     object
#  1   Gender      10 non-null     object
#  2   DOB         10 non-null     object
#  3   Maths       10 non-null     int64
#  4   Physics     10 non-null     int64
#  5   Chemistry   10 non-null     int64
#  6   English     10 non-null     int64
#  7   Biology     10 non-null     int64
#  8   Economics   10 non-null     int64
#  9   History     10 non-null     int64
#  10  Civics      10 non-null     int64
# dtypes: int64(8), object(3)
# memory usage: 1012.0+ bytes

# %%
#Statistical Summary of Data
df.describe()
# Out:
#            Maths    Physics  Chemistry    English    Biology  Economics  \
# count  10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean   59.600000  72.300000  75.300000  69.700000  64.700000  72.700000
# std    19.460501  20.661559  14.000397  14.453373  26.998148  14.629119
# min    25.000000  45.000000  52.000000  46.000000  21.000000  52.000000
# 25%    54.250000  56.250000  65.000000  59.250000  54.250000  58.750000
# 50%    55.000000  70.000000  78.000000  69.500000  66.500000  76.000000
# 75%    70.750000  93.750000  86.750000  81.250000  87.000000  86.000000
# max    96.000000  96.000000  89.000000  89.000000  96.000000  89.000000
#
#          History   Civics
# count  10.000000  10.0000
# mean   69.700000  60.5000
# std    14.453373  25.3432
# min    46.000000   2.0000
# 25%    59.250000  52.2500
# 50%    69.500000  63.0000
# 75%    81.250000  76.2500
# max    89.000000  89.0000

# %%
df.isnull().any()
# Out:
# Unnamed: 0    False
# Gender        False
# DOB           False
# Maths         False
# Physics       False
# Chemistry     False
# English       False
# Biology       False
# Economics     False
# History       False
# Civics        False
# dtype: bool

# %%
#Checking Null values
df.isnull()
# Out:
#    Unnamed: 0  Gender    DOB  Maths  Physics  Chemistry  English  Biology  \
# 0       False   False  False  False    False      False    False    False
# 1       False   False  False  False    False      False    False    False
# 2       False   False  False  False    False      False    False    False
# 3       False   False  False  False    False      False    False    False
# 4       False   False  False  False    False      False    False    False
# 5       False   False  False  False    False      False    False    False
# 6       False   False  False  False    False      False    False    False
# 7       False   False  False  False    False      False    False    False
# 8       False   False  False  False    False      False    False    False
# 9       False   False  False  False    False      False    False    False
#
#    Economics  History  Civics
# 0      False    False   False
# 1      False    False   False
# 2      False    False   False
# ...

# %%
#Checking Total Null values
df.isnull().sum()
# Out:
# Unnamed: 0    0
# Gender        0
# DOB           0
# Maths         0
# Physics       0
# Chemistry     0
# English       0
# Biology       0
# Economics     0
# History       0
# Civics        0
# dtype: int64

# %%
#Transpose of Statistical summary of data
df.describe().T
# Out:
#            count  mean        std   min    25%   50%    75%   max
# Maths       10.0  59.6  19.460501  25.0  54.25  55.0  70.75  96.0
# Physics     10.0  72.3  20.661559  45.0  56.25  70.0  93.75  96.0
# Chemistry   10.0  75.3  14.000397  52.0  65.00  78.0  86.75  89.0
# English     10.0  69.7  14.453373  46.0  59.25  69.5  81.25  89.0
# Biology     10.0  64.7  26.998148  21.0  54.25  66.5  87.00  96.0
# Economics   10.0  72.7  14.629119  52.0  58.75  76.0  86.00  89.0
# History     10.0  69.7  14.453373  46.0  59.25  69.5  81.25  89.0
# Civics      10.0  60.5  25.343200   2.0  52.25  63.0  76.25  89.0

# %%
#Checking every elements of total count in a column
df['Maths'].value_counts()
# Out:
# Maths
# 55    3
# 75    1
# 25    1
# 78    1
# 58    1
# 45    1
# 54    1
# 96    1
# Name: count, dtype: int64

# %%
#Sorting every elements of total count in a column
(df['Maths'].value_counts()).sort_values(ascending=False)
# Out:
# Maths
# 55    3
# 75    1
# 25    1
# 78    1
# 58    1
# 45    1
# 54    1
# 96    1
# Name: count, dtype: int64

# %%
#Sorting every elements of total count in a column
(df['Maths'].value_counts()).sort_values()
# Out:
# Maths
# 75    1
# 25    1
# 78    1
# 58    1
# 54    1
# 45    1
# 96    1
# 55    3
# Name: count, dtype: int64

# %%
#Sorting every elements based on Region column
df.sort_values('Maths')
# Out:
#   Unnamed: 0 Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 2     Ramesh      M  25-05-1989     25       54         89       76       95
# 5       Annu      F  05-04-1988     45       87         52       89       55
# 7     Ritesh      M  25-05-1989     54       76         87       56       25
# 0       John      M  05-04-1988     55       45         56       87       21
# 6      pooja      F  04-05-1987     55       64         61       58       75
# 8      Farha      F  12-08-1990     55       63         89       75       78
# 4   Jennifer      F  02-09-1989     58       96         78       46       96
# 1     Suresh      M  04-05-1987     75       96         78       64       90
# 3    Jessica      F  12-08-1990     78       96         86       63       54
# 9     Mukesh      M  02-09-1989     96       46         77       83       58
#
#    Economics  History  Civics
# 2         87       56      74
# 5         89       87      52
# ...

# %%
#Sorting every elements based on BMI column
df.sort_values('Maths')
# Out:
#   Unnamed: 0 Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 2     Ramesh      M  25-05-1989     25       54         89       76       95
# 5       Annu      F  05-04-1988     45       87         52       89       55
# 7     Ritesh      M  25-05-1989     54       76         87       56       25
# 0       John      M  05-04-1988     55       45         56       87       21
# 6      pooja      F  04-05-1987     55       64         61       58       75
# 8      Farha      F  12-08-1990     55       63         89       75       78
# 4   Jennifer      F  02-09-1989     58       96         78       46       96
# 1     Suresh      M  04-05-1987     75       96         78       64       90
# 3    Jessica      F  12-08-1990     78       96         86       63       54
# 9     Mukesh      M  02-09-1989     96       46         77       83       58
#
#    Economics  History  Civics
# 2         87       56      74
# 5         89       87      52
# ...

# %%
#Checking count of Age column
df['DOB'].value_counts()
# Out:
# DOB
# 05-04-1988    2
# 04-05-1987    2
# 25-05-1989    2
# 12-08-1990    2
# 02-09-1989    2
# Name: count, dtype: int64

# %%
# Short 2 columns age and region.
df.sort_values(['Maths','English'])
# Out:
#   Unnamed: 0 Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 2     Ramesh      M  25-05-1989     25       54         89       76       95
# 5       Annu      F  05-04-1988     45       87         52       89       55
# 7     Ritesh      M  25-05-1989     54       76         87       56       25
# 6      pooja      F  04-05-1987     55       64         61       58       75
# 8      Farha      F  12-08-1990     55       63         89       75       78
# 0       John      M  05-04-1988     55       45         56       87       21
# 4   Jennifer      F  02-09-1989     58       96         78       46       96
# 1     Suresh      M  04-05-1987     75       96         78       64       90
# 3    Jessica      F  12-08-1990     78       96         86       63       54
# 9     Mukesh      M  02-09-1989     96       46         77       83       58
#
#    Economics  History  Civics
# 2         87       56      74
# 5         89       87      52
# ...

# %%
#Checking duplicate values
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#Checking for group by values
Charges_ins=df.groupby(["Gender"]) ["English"].sum()
Charges_ins
# Out:
# Gender
# F    331
# M    366
# Name: English, dtype: int64

# %%
# length of dataset
len(df)
# Out:
# 10

# %%
Charges_ins.size()
# Out:
# Gender
# F    5
# M    5
# dtype: int64

# %%
df['Maths'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Maths'>

# %%
#To check Children ratio
df['Gender'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
#To check Region ratio
df['Biology'].value_counts().plot(kind='pie', autopct='%1.1f%%', title='Marks Distribution')
plt.ylabel('') # Remove default 'count' label
plt.show()

# %%
# To check Distribution of Passenger Class
df['Maths'].value_counts().plot(kind='bar', title='Distribution of Marks')
plt.xlabel('charges')
plt.ylabel('Count')
plt.show()

# %%
#To Check Ratio of male & female
df['Gender'].value_counts().plot(kind='pie', autopct='%1.1f%%', title='Sex Distribution')
plt.show()

# %%
#To Check Ratio of male & female
df['Gender'].value_counts().plot(kind='bar', title='Sex Distribution')
plt.show()

# %%
#Age Distributuion of insurance
sns.histplot(df['English'])
plt.title(f"maks")
plt.show()

# %%
df["Civics"]
# Out:
# 0    65
# 1     2
# 2    74
# 3    45
# 4    53
# 5    52
# 6    61
# 7    87
# 8    89
# 9    77
# Name: Civics, dtype: int64

# %%
#charges distribution
sns.histplot(df['Civics'])
plt.title(f"charges")
plt.show()

# %%
#countplot for Smoker people
sns.countplot(x="Civics", data=df,hue="Maths")
plt.show()

# %%
#countplot for male/female people
sns.countplot(x="Gender", data=df)
plt.show()

# %%
sns.displot(data=df,x="English",hue="Maths",kind='kde',fill=True)
# Out:
# C:\Users\Bailw\AppData\Local\Temp\ipykernel_14460\3518922994.py:1: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.displot(data=df,x="English",hue="Maths",kind='kde',fill=True)

# %%
sns.pairplot(df,hue='Maths')
